# %%
import pandas as pd

# %%
df1 = pd.read_csv('Without Yeo Johnson 70-30 Applying SFS Top 4 features.csv')
df2 = pd.read_csv('Without Yeo Johnson 70-30 Applying SFS Top 5 features.csv')
df3 = pd.read_csv('Without Yeo Johnson 70-30 Applying SFS Top 7 features.csv')
df4 = pd.read_csv('Without Yeo Johnson 70-30 Applying SFS Top 9 features.csv')

# %%
df4
# Out:
#   Unnamed: 0         0                   1       2                   3  \
# 0    Metrics  Accuracy           Precision  Recall            F1 Score
# 1        SVC    0.9125   0.919583931133429  0.9125   0.900477127039627
# 2         LR      0.95  0.9548780487804878    0.95  0.9482223186170554
# 3        KNN     0.875  0.8620979532163744   0.875   0.861078431372549
#
#                     4                   5
# 0         Cohen Kappa                 AUC
# 1  0.8502673796791445  0.9690782243214467
# 2  0.9158559032342887   0.977738451824492
# 3  0.7881355932203389  0.9355522606804284

# %%
df2 = df2.drop(0, axis=0)
df3 = df3.drop(0, axis=0)
df4 = df4.drop(0, axis=0)
df2
# Out:
#   Unnamed: 0       0                   1       2                   3  \
# 1        SVC  0.9125  0.9143849206349206  0.9125  0.9098057169537249
# 2         LR   0.875  0.8970108695652174   0.875  0.8421570898980537
# 3        KNN     0.9  0.9043201754385966     0.9  0.9015123889668069
#
#                     4                   5
# 1  0.8533647551715109   0.963293501607534
# 2  0.7809419496166484  0.9829180838130851
# 3  0.8359815479241415  0.9545851854963016

# %%
df = pd.concat([df1, df2, df3, df4])
df
# Out:
#   Unnamed: 0         0                   1       2                   3  \
# 0    Metrics  Accuracy           Precision  Recall            F1 Score
# 1        SVC    0.9125  0.9143849206349206  0.9125  0.9098057169537249
# 2         LR     0.875  0.8970108695652174   0.875  0.8421570898980537
# 3        KNN       0.9  0.9043201754385966     0.9  0.9015123889668069
# 1        SVC    0.9125  0.9143849206349206  0.9125  0.9098057169537249
# 2         LR     0.875  0.8970108695652174   0.875  0.8421570898980537
# 3        KNN       0.9  0.9043201754385966     0.9  0.9015123889668069
# 1        SVC     0.875  0.8961775362318841   0.875  0.8598762793107916
# 2         LR    0.9125  0.9264204545454545  0.9125  0.9021191578483245
# 3        KNN       0.8  0.8176785714285714     0.8   0.807427308882015
# 1        SVC    0.9125   0.919583931133429  0.9125   0.900477127039627
# 2         LR      0.95  0.9548780487804878    0.95  0.9482223186170554
# ...

# %%
df = df.drop(0, axis=0)

# %%
df.rename(columns={'Unnamed: 0': 'Model', '0': 'Accuracy', '1': 'Precision', '2': 'Recall', '3': 'F1 Score', '4': 'Cohen Kappa', '5': 'AUC'}, inplace=True)

# %%
df
# Out:
#   Model Accuracy           Precision  Recall            F1 Score  \
# 1   SVC   0.9125  0.9143849206349206  0.9125  0.9098057169537249
# 2    LR    0.875  0.8970108695652174   0.875  0.8421570898980537
# 3   KNN      0.9  0.9043201754385966     0.9  0.9015123889668069
# 1   SVC   0.9125  0.9143849206349206  0.9125  0.9098057169537249
# 2    LR    0.875  0.8970108695652174   0.875  0.8421570898980537
# 3   KNN      0.9  0.9043201754385966     0.9  0.9015123889668069
# 1   SVC    0.875  0.8961775362318841   0.875  0.8598762793107916
# 2    LR   0.9125  0.9264204545454545  0.9125  0.9021191578483245
# 3   KNN      0.8  0.8176785714285714     0.8   0.807427308882015
# 1   SVC   0.9125   0.919583931133429  0.9125   0.900477127039627
# 2    LR     0.95  0.9548780487804878    0.95  0.9482223186170554
# 3   KNN    0.875  0.8620979532163744   0.875   0.861078431372549
#
#           Cohen Kappa                 AUC
# 1  0.8533647551715109  0.9665242839298073
# ...

# %%
df = df.sort_values('Model')

# %%
df
# Out:
#   Model Accuracy           Precision  Recall            F1 Score  \
# 3   KNN      0.9  0.9043201754385966     0.9  0.9015123889668069
# 3   KNN      0.9  0.9043201754385966     0.9  0.9015123889668069
# 3   KNN      0.8  0.8176785714285714     0.8   0.807427308882015
# 3   KNN    0.875  0.8620979532163744   0.875   0.861078431372549
# 2    LR    0.875  0.8970108695652174   0.875  0.8421570898980537
# 2    LR    0.875  0.8970108695652174   0.875  0.8421570898980537
# 2    LR   0.9125  0.9264204545454545  0.9125  0.9021191578483245
# 2    LR     0.95  0.9548780487804878    0.95  0.9482223186170554
# 1   SVC   0.9125  0.9143849206349206  0.9125  0.9098057169537249
# 1   SVC   0.9125  0.9143849206349206  0.9125  0.9098057169537249
# 1   SVC    0.875  0.8961775362318841   0.875  0.8598762793107916
# 1   SVC   0.9125   0.919583931133429  0.9125   0.900477127039627
#
#           Cohen Kappa                 AUC
# 3  0.8359815479241415  0.9545851854963016
# ...

# %%
df.to_csv('Combined accuracy without YJ/Without Yeo Johnson 70-30 Applying SFS.csv', index=False)
