# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline    
from sklearn.model_selection import train_test_split
from numpy import mean
from numpy import std

# %%
data = pd.read_csv('Unique_ Iraqi Y.csv')

# %%
data.shape
# Out:
# (690, 12)

# %%
data
# Out:
#      Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI  Class
# 0         0   50   4.0   56   13.7   4.4  2.0  1.0  2.5   0.9  29.0      2
# 1         0   48   4.0   38    6.5   4.4  2.3  1.3  2.2   1.0  23.0      2
# 2         0   46   3.0   59    5.1   5.7  3.8  1.3  2.8   1.7  24.0      2
# 3         0   54   3.0   39    7.2   9.5  1.7  1.3  2.5   0.6  22.0      2
# 4         0   49   3.8   56    5.1   6.0  3.5  1.1  3.5   1.6  25.0      2
# ..      ...  ...   ...  ...    ...   ...  ...  ...  ...   ...   ...    ...
# 685       1   62   6.3   82    6.7   5.3  2.0  1.0  3.5   0.9  30.1      2
# 686       1   55   3.1   39    8.5   5.0  2.5  1.9  2.9   0.7  27.0      2
# 687       1   28   3.5   61    8.5   4.5  1.9  1.1  2.6   0.8  37.0      2
# 688       1   69  10.3  185    7.7   4.9  1.9  1.2  3.0   0.7  37.0      2
# 689       1   71  11.0   97    7.0   7.5  1.7  1.2  1.8   0.6  30.0      2
#
# [690 rows x 12 columns]

# %%
data['AGE'].max(), data['AGE'].min()
# Out:
# (79, 20)

# %%
range_min = data['AGE'].min()
range_max = data['AGE'].max()
subset = data[(data['AGE'] >= range_min) & (data['AGE'] < range_max)]

# %%
# markers = ['+', 'o',]
# column = ['Urea', 'HbA1c']
# for x, t in zip(data.column, data.markers):
#     plt.scatter(x, marker = t)

# %%
plt.scatter(data[['Urea']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 plt.scatter(data[['Urea']])
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
data['HbA1c'].max(), data['HbA1c'].min()
# Out:
# (16.0, 2.0)

# %%
data['Chol'].max(), data['Chol'].min()
# Out:
# (10.3, 0.6)

# %%
data['HbA1c'].random(8-10)

# %%
# Define the range values for each feature
range_values = {
    'HbA1c': [(2, 4), (4, 6), (6, 8), (8, 10), (10, 12), (12, 14), (14, 16) ],
    'Chol': [(-3.08, 1), (1, 3.09)]
}

# Iterate over the range values and check the data within the specified range
for feature, ranges in range_values.items():
    # print(f"Values within the range for {feature}:")
    for range_min, range_max in ranges:
        subset = data[(data[feature] >= range_min) & (data[feature] < range_max)]
        # print(f"Range {range_min}-{range_max}: {subset}")

        print(subset)
# Out:
#      Gender  AGE  Urea  Cr  HbA1c  Chol    TG  HDL  LDL  VLDL    BMI  Class
# 134       0   55   4.9  63    3.7   6.1  1.60  1.4  4.0   0.7  26.00      2
# 139       0   55   4.9  63    3.7   6.1  1.60  1.4  4.0   0.7  34.00      2
# 461       1   60   5.6  74    2.0   5.2  2.00  1.6  1.8   1.0  33.00      2
# 538       1   54   5.4  68    3.0   1.2  0.70  1.0  0.5   1.5  33.00      2
# 540       1   55   5.0  81    3.7   5.7  1.19  1.1  4.1   8.1  35.16      2
#      Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL   LDL  VLDL   BMI  Class
# 2         0   46   3.0   59    5.1   5.7  3.8  1.3  2.80   1.7  24.0      2
# 4         0   49   3.8   56    5.1   6.0  3.5  1.1  3.50   1.6  25.0      2
# 5         0   45   3.1   54    4.0   5.9  1.8  1.6  3.50   0.8  24.0      2
# 6         0   47   3.5   65    5.0   6.3  2.2  1.1  2.80   0.8  23.0      2
# 7         0   42   2.8   39    4.6   4.7  2.5  1.3  2.40   1.1  25.0      2
# ...
